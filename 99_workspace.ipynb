# %% [markdown]
# # dataset load

# %%
from collections import Counter
from datasets import load_dataset
from tqdm import tqdm

# %%
# data download
dataset = load_dataset("McAuley-Lab/Amazon-Reviews-2023", "raw_review_Clothing_Shoes_and_Jewelry", trust_remote_code=True)
print(dataset["full"][0])
# Out:
# Using the latest cached version of the module from /Users/suhyeon/.cache/huggingface/modules/datasets_modules/datasets/McAuley-Lab--Amazon-Reviews-2023/16b76e0823d73bb8cff1e9c5e3e37dbc46ae3daee380417ae141f5e67d3ea8e8 (last modified on Mon Apr 29 14:04:54 2024) since it couldn't be found locally at McAuley-Lab/Amazon-Reviews-2023, or remotely on the Hugging Face Hub.
# Loading dataset shards:   0%|          | 0/20 [00:00<?, ?it/s]
# {'rating': 3.0, 'title': 'Arrived Damaged : liquid in hub locker!', 'text': 'Unfortunately Amazon in their wisdom (cough, cough) decided to ship the snowsuit in a vinyl bag with holes in it!  There was no other bag to protect the snowsuit inside vinyl bag with all the holes.  This is what happened:  Arrived in hub locker. It was the very top locker. Opened it & pulled the pkg out getting a very wet & nasty surprise at the same time. My senses were assaulted. Smells like tea tree oil. Feels like conditioner or lotion.  I can’t understand how the delivery person a) didn’t smell that mess when they shoved the pkg in b) didn’t see the mess when they shoved it in - tho if they were short I guess that would explain it bc I’m 5’10” & I didn’t see it until the pkg was in my hands. The locker was up high & dark, but I could smell it the minute I walked into the hub locker room. I happen to be extremely allergic to tea tree oil.  It’s made from mellaleuca trees which grow all over southwest Florida where I was raised.  Tho native to Australia they were used to help drain the swamps of Florida generations ago bc they soak up so much water.  It has a very distinct smell & unfortunately is frequently used as a “carrier oil” for other oils & body lotions,  shampoos, conditioners, etc., so I have to be hyper-vigilant to avoid exposure.  Instead- Last night I got to suck down Benadryl & pray my throat didn’t close while keeping my epi-pens handy.  The liquid went through the holes & onto the snowsuit as you can clearly see in the pictures.  So I guess the suit is waterproof.  Looks true to size.  Elastic appears stretchy.  I’m super annoyed that this arrived in this condition & could have easily been avoided by amazon properly wrapping it to avoid the elements whatever they may be.', 'images': [{'attachment_type': 'IMAGE', 'large_image_url': 'https://m.media-amazon.com/images/I/710WrjJi+hL._SL1600_.jpg', 'medium_image_url': 'https://m.media-amazon.com/images/I/710WrjJi+hL._SL800_.jpg', 'small_image_url': 'https://m.media-amazon.com/images/I/710WrjJi+hL._SL256_.jpg'}, {'attachment_type': 'IMAGE', 'large_image_url': 'https://m.media-amazon.com/images/I/712+yNg8COL._SL1600_.jpg', 'medium_image_url': 'https://m.media-amazon.com/images/I/712+yNg8COL._SL800_.jpg', 'small_image_url': 'https://m.media-amazon.com/images/I/712+yNg8COL._SL256_.jpg'}, {'attachment_type': 'IMAGE', 'large_image_url': 'https://m.media-amazon.com/images/I/7132ByALa+L._SL1600_.jpg', 'medium_image_url': 'https://m.media-amazon.com/images/I/7132ByALa+L._SL800_.jpg', 'small_image_url': 'https://m.media-amazon.com/images/I/7132ByALa+L._SL256_.jpg'}, {'attachment_type': 'IMAGE', 'large_image_url': 'https://m.media-amazon.com/images/I/718OTnxL+CL._SL1600_.jpg', 'medium_image_url': 'https://m.media-amazon.com/images/I/718OTnxL+CL._SL800_.jpg', 'small_image_url': 'https://m.media-amazon.com/images/I/718OTnxL+CL._SL256_.jpg'}, {'attachment_type': 'IMAGE', 'large_image_url': 'https://m.media-amazon.com/images/I/71I6b8DyazL._SL1600_.jpg', 'medium_image_url': 'https://m.media-amazon.com/images/I/71I6b8DyazL._SL800_.jpg', 'small_image_url': 'https://m.media-amazon.com/images/I/71I6b8DyazL._SL256_.jpg'}, {'attachment_type': 'IMAGE', 'large_image_url': 'https://m.media-amazon.com/images/I/71v4KKrIXuL._SL1600_.jpg', 'medium_image_url': 'https://m.media-amazon.com/images/I/71v4KKrIXuL._SL800_.jpg', 'small_image_url': 'https://m.media-amazon.com/images/I/71v4KKrIXuL._SL256_.jpg'}], 'asin': 'B096S6LZV4', 'parent_asin': 'B09NSZ5QMF', 'user_id': 'AFKZENTNBQ7A7V7UXW5JJI6UGRYQ', 'timestamp': 1677938767351, 'helpful_vote': 0, 'verified_purchase': True}

# %%
meta_dataset = load_dataset("McAuley-Lab/Amazon-Reviews-2023", "raw_meta_Clothing_Shoes_and_Jewelry", split="full", trust_remote_code=True)
print(meta_dataset[0])
# Out:
# Loading dataset shards:   0%|          | 0/31 [00:00<?, ?it/s]
# {'main_category': 'AMAZON FASHION', 'title': "BALEAF Women's Long Sleeve Zip Beach Coverup UPF 50+ Sun Protection Hooded Cover Up Shirt Dress with Pockets", 'average_rating': 4.2, 'rating_number': 422, 'features': ['90% Polyester, 10% Spandex', 'Zipper closure', 'Machine Wash', 'Long sleeve sun protection coverups--UPF 50+ blocks the sun from burning', 'Zipped v-neckline--fashionable V neck and smooth 1/4 zipper allows to staying place as you like', 'Two drop-in side pockets--hold your phone or keys well，no worries of falling out', 'Hoodie with non-slip drawcord--Enhancing hooded design is convenient to wrap your face and enough space to put your head and hair easily', 'A flattering coverups company you spend all day on the beach，traveling with lovers or busying around house. Recommended For everyday leisure or daily exercise'], 'description': [], 'price': '31.99', 'images': {'hi_res': ['https://m.media-amazon.com/images/I/61KIZjb54AL._AC_UL1500_.jpg', 'https://m.media-amazon.com/images/I/61OkTrsW88L._AC_UL1500_.jpg', 'https://m.media-amazon.com/images/I/811lbVuVIAL._AC_UL1500_.jpg', 'https://m.media-amazon.com/images/I/71wa-UQGlYL._AC_UL1500_.jpg', 'https://m.media-amazon.com/images/I/61tspZIpHqL._AC_UL1500_.jpg', 'https://m.media-amazon.com/images/I/71oVECB3VYL._AC_UL1500_.jpg'], 'large': ['https://m.media-amazon.com/images/I/31zPYU+UkVL._AC_.jpg', 'https://m.media-amazon.com/images/I/31LYNX5KQ6L._AC_.jpg', 'https://m.media-amazon.com/images/I/51dD8Ga+wQL._AC_.jpg', 'https://m.media-amazon.com/images/I/41kM3Cn3ERL._AC_.jpg', 'https://m.media-amazon.com/images/I/41ZzITDO+OL._AC_.jpg', 'https://m.media-amazon.com/images/I/51jTzfIP3dL._AC_.jpg'], 'thumb': ['https://m.media-amazon.com/images/I/31zPYU+UkVL._AC_SR38,50_.jpg', 'https://m.media-amazon.com/images/I/31LYNX5KQ6L._AC_SR38,50_.jpg', 'https://m.media-amazon.com/images/I/51dD8Ga+wQL._AC_SR38,50_.jpg', 'https://m.media-amazon.com/images/I/41kM3Cn3ERL._AC_SR38,50_.jpg', 'https://m.media-amazon.com/images/I/41ZzITDO+OL._AC_SR38,50_.jpg', 'https://m.media-amazon.com/images/I/51jTzfIP3dL._AC_SR38,50_.jpg'], 'variant': ['MAIN', 'PT01', 'PT02', 'PT03', 'PT04', 'PT05']}, 'videos': {'title': ["Women's UPF 50+ Front Zip Beach Coverups with Pockets", " Women's Swim Cover Up Dress"], 'url': ['https://www.amazon.com/vdp/0041f3df9f604577bd982078c9f3fec2?ref=dp_vse_rvc_0', 'https://www.amazon.com/vdp/0222bb314b16471a8b43f19080358fdc?ref=dp_vse_rvc_1'], 'user_id': ['', '']}, 'store': 'BALEAF', 'categories': ['Clothing, Shoes & Jewelry', 'Women', 'Clothing', 'Swimsuits & Cover Ups', 'Cover-Ups'], 'details': '{"Department": "womens", "Date First Available": "April 3, 2022"}', 'parent_asin': 'B09X1MRDN6', 'bought_together': None, 'subtitle': None, 'author': None}

# %%
# check data format
dataset
# Out:
# DatasetDict({
#     full: Dataset({
#         features: ['rating', 'title', 'text', 'images', 'asin', 'parent_asin', 'user_id', 'timestamp', 'helpful_vote', 'verified_purchase'],
#         num_rows: 32870495
#     })
# })

# %%
# total review count
len(dataset['full'])
# Out:
# 32870495

# %%
# review with image
k=0
for i in range(len(dataset['full'])):
    if (dataset['full'][i]['images']):
        k += 1
print(k)

# %%
# 한 리뷰에 이미지 수가 몇개인지 확인
img_cnt = [len(item['images']) for item in dataset['full'] if item['images']]

# %%
# 이미지 수 리스트인 img_cnt에서 각 값의 빈도수를 세기
distribution = Counter(img_cnt)

# 결과 출력
print(distribution)
# Out:
# Counter({1: 1050830, 2: 398621, 3: 173493, 4: 75249, 5: 32675, 6: 17058, 7: 8401, 8: 5031, 9: 2747, 10: 1894, 11: 1058, 12: 783, 13: 460, 14: 358, 15: 229, 16: 177, 17: 110, 18: 105, 19: 70, 20: 58, 21: 33, 24: 24, 22: 22, 26: 17, 23: 16, 30: 15, 25: 12, 28: 10, 29: 2, 27: 2, 32: 2, 247: 1, 34: 1, 64: 1, 37: 1, 31: 1, 47: 1, 63: 1, 62: 1, 43: 1, 40: 1})

# %%
# meta 데이터랑 Merge
# meta 의 'parent_asin'변수 랑 review의 'parent_asin'랑 매치
# meta에 'review' dict 추가, 기존에 있던 리뷰 append

meta_dataset = [{'main_category': 'AMAZON FASHION', 'title': "BALEAF Women's Long Sleeve Zip Beach Coverup UPF 50+ Sun Protection Hooded Cover Up Shirt Dress with Pockets", 'average_rating': 4.2, 
                 'rating_number': 422, 'features': ['90% Polyester, 10% Spandex', 'Zipper closure', 'Machine Wash', 'Long sleeve sun protection coverups--UPF 50+ blocks the sun from burning', 'Zipped v-neckline--fashionable V neck and smooth 1/4 zipper allows to staying place as you like', 'Two drop-in side pockets--hold your phone or keys well，no worries of falling out', 'Hoodie with non-slip drawcord--Enhancing hooded design is convenient to wrap your face and enough space to put your head and hair easily', 'A flattering coverups company you spend all day on the beach，traveling with lovers or busying around house. Recommended For everyday leisure or daily exercise'], 
                 'description': [], 'price': 31.99, 
                 'images': [{'thumb': 'https://m.media-amazon.com/images/I/31zPYU+UkVL._AC_SR38,50_.jpg', 'large': 'https://m.media-amazon.com/images/I/31zPYU+UkVL._AC_.jpg', 'variant': 'MAIN', 'hi_res': 'https://m.media-amazon.com/images/I/61KIZjb54AL._AC_UL1500_.jpg'}, 
                            {'thumb': 'https://m.media-amazon.com/images/I/31LYNX5KQ6L._AC_SR38,50_.jpg', 'large': 'https://m.media-amazon.com/images/I/31LYNX5KQ6L._AC_.jpg', 'variant': 'PT01', 'hi_res': 'https://m.media-amazon.com/images/I/61OkTrsW88L._AC_UL1500_.jpg'}, 
                            {'thumb': 'https://m.media-amazon.com/images/I/51dD8Ga+wQL._AC_SR38,50_.jpg', 'large': 'https://m.media-amazon.com/images/I/51dD8Ga+wQL._AC_.jpg', 'variant': 'PT02', 'hi_res': 'https://m.media-amazon.com/images/I/811lbVuVIAL._AC_UL1500_.jpg'}, 
                            {'thumb': 'https://m.media-amazon.com/images/I/41kM3Cn3ERL._AC_SR38,50_.jpg', 'large': 'https://m.media-amazon.com/images/I/41kM3Cn3ERL._AC_.jpg', 'variant': 'PT03', 'hi_res': 'https://m.media-amazon.com/images/I/71wa-UQGlYL._AC_UL1500_.jpg'}, 
                            {'thumb': 'https://m.media-amazon.com/images/I/41ZzITDO+OL._AC_SR38,50_.jpg', 'large': 'https://m.media-amazon.com/images/I/41ZzITDO+OL._AC_.jpg', 'variant': 'PT04', 'hi_res': 'https://m.media-amazon.com/images/I/61tspZIpHqL._AC_UL1500_.jpg'}, 
                            {'thumb': 'https://m.media-amazon.com/images/I/51jTzfIP3dL._AC_SR38,50_.jpg', 'large': 'https://m.media-amazon.com/images/I/51jTzfIP3dL._AC_.jpg', 'variant': 'PT05', 'hi_res': 'https://m.media-amazon.com/images/I/71oVECB3VYL._AC_UL1500_.jpg'}], 
                 'videos': [{'title': "Women's UPF 50+ Front Zip Beach Coverups with Pockets", 'url': 'https://www.amazon.com/vdp/0041f3df9f604577bd982078c9f3fec2?ref=dp_vse_rvc_0', 'user_id': ''}, 
                            {'title': " Women's Swim Cover Up Dress", 'url': 'https://www.amazon.com/vdp/0222bb314b16471a8b43f19080358fdc?ref=dp_vse_rvc_1', 'user_id': ''}], 
                 'store': 'BALEAF', 'categories': ['Clothing, Shoes & Jewelry', 'Women', 'Clothing', 'Swimsuits & Cover Ups', 'Cover-Ups'], 
                 'details': {'Department': 'womens', 'Date First Available': 'April 3, 2022'}, 
                 'parent_asin': 'B09X1MRDN6', 'bought_together': None}
                
                ,{'main_category': 'AMAZON FASHION', 'title': 'Merrell Work Moab 2 Vent Waterproof SR Boulder', 'average_rating': 2.7, 
                  'rating_number': 4, 'features': ['Rubber sole'], 
                  'description': [], 'price': None, 
                  'images': [{'thumb': 'https://m.media-amazon.com/images/I/41TeICZuYgL._AC_US40_.jpg', 'large': 'https://m.media-amazon.com/images/I/41TeICZuYgL._AC_.jpg', 'variant': 'MAIN', 'hi_res': 'https://m.media-amazon.com/images/I/81oltcdwYSL._AC_UL1500_.jpg'}], 
                  'videos': [], 'store': 'Merrell', 'categories': ['Clothing, Shoes & Jewelry', 'Women', 'Shoes', 'Outdoor', 'Hiking & Trekking', 'Hiking Shoes'], 
                  'details': {'Package Dimensions': '14.02 x 9.29 x 4.8 inches; 1 Pounds', 'Item model number': '00-3C4Q7W8I-AX', 'Department': 'womens', 'Date First Available': 'November 2, 2017'}, 
                  'parent_asin': 'B073C4Q7W8', 'bought_together': None}
]

dataset['full'] = [{'rating': 3.0, 'title': 'Arrived Damaged : liquid in hub locker!', 
                    'text': 'Unfortunately Amazon in their wisdom (cough, cough) decided to ship the snowsuit in a vinyl bag with holes in it!  There was no other bag to protect the snowsuit inside vinyl bag with all the holes.  This is what happened:  Arrived in hub locker. It was the very top locker. Opened it & pulled the pkg out getting a very wet & nasty surprise at the same time. My senses were assaulted. Smells like tea tree oil. Feels like conditioner or lotion.  I can’t understand how the delivery person a) didn’t smell that mess when they shoved the pkg in b) didn’t see the mess when they shoved it in - tho if they were short I guess that would explain it bc I’m 5’10” & I didn’t see it until the pkg was in my hands. The locker was up high & dark, but I could smell it the minute I walked into the hub locker room. I happen to be extremely allergic to tea tree oil.  It’s made from mellaleuca trees which grow all over southwest Florida where I was raised.  Tho native to Australia they were used to help drain the swamps of Florida generations ago bc they soak up so much water.  It has a very distinct smell & unfortunately is frequently used as a “carrier oil” for other oils & body lotions,  shampoos, conditioners, etc., so I have to be hyper-vigilant to avoid exposure.  Instead- Last night I got to suck down Benadryl & pray my throat didn’t close while keeping my epi-pens handy.  The liquid went through the holes & onto the snowsuit as you can clearly see in the pictures.  So I guess the suit is waterproof.  Looks true to size.  Elastic appears stretchy.  I’m super annoyed that this arrived in this condition & could have easily been avoided by amazon properly wrapping it to avoid the elements whatever they may be.', 
                    'images': [{'attachment_type': 'IMAGE', 'large_image_url': 'https://m.media-amazon.com/images/I/710WrjJi+hL._SL1600_.jpg', 'medium_image_url': 'https://m.media-amazon.com/images/I/710WrjJi+hL._SL800_.jpg', 'small_image_url': 'https://m.media-amazon.com/images/I/710WrjJi+hL._SL256_.jpg'}, {'attachment_type': 'IMAGE', 'large_image_url': 'https://m.media-amazon.com/images/I/712+yNg8COL._SL1600_.jpg', 'medium_image_url': 'https://m.media-amazon.com/images/I/712+yNg8COL._SL800_.jpg', 'small_image_url': 'https://m.media-amazon.com/images/I/712+yNg8COL._SL256_.jpg'}, {'attachment_type': 'IMAGE', 'large_image_url': 'https://m.media-amazon.com/images/I/7132ByALa+L._SL1600_.jpg', 'medium_image_url': 'https://m.media-amazon.com/images/I/7132ByALa+L._SL800_.jpg', 'small_image_url': 'https://m.media-amazon.com/images/I/7132ByALa+L._SL256_.jpg'}, 
                               {'attachment_type': 'IMAGE', 'large_image_url': 'https://m.media-amazon.com/images/I/718OTnxL+CL._SL1600_.jpg', 'medium_image_url': 'https://m.media-amazon.com/images/I/718OTnxL+CL._SL800_.jpg', 'small_image_url': 'https://m.media-amazon.com/images/I/718OTnxL+CL._SL256_.jpg'}, {'attachment_type': 'IMAGE', 'large_image_url': 'https://m.media-amazon.com/images/I/71I6b8DyazL._SL1600_.jpg', 'medium_image_url': 'https://m.media-amazon.com/images/I/71I6b8DyazL._SL800_.jpg', 'small_image_url': 'https://m.media-amazon.com/images/I/71I6b8DyazL._SL256_.jpg'}, {'attachment_type': 'IMAGE', 'large_image_url': 'https://m.media-amazon.com/images/I/71v4KKrIXuL._SL1600_.jpg', 'medium_image_url': 'https://m.media-amazon.com/images/I/71v4KKrIXuL._SL800_.jpg', 'small_image_url': 'https://m.media-amazon.com/images/I/71v4KKrIXuL._SL256_.jpg'}], 
                    'asin': 'B096S6LZV4', 'parent_asin': 'B073C4Q7W8', 'user_id': 'AFKZENTNBQ7A7V7UXW5JJI6UGRYQ', 'timestamp': 1677938767351, 'helpful_vote': 0, 'verified_purchase': True}, 
                   
                   {'rating': 2.0, 'title': 'test2', 
                    'text': 'Unfortunately Amazon in their wisdom (cough, cough) decided to ship the snowsuit in a vinyl bag with holes in it!  There was no other bag to protect the snowsuit inside vinyl bag with all the holes.  This is what happened:  Arrived in hub locker. It was the very top locker. Opened it & pulled the pkg out getting a very wet & nasty surprise at the same time. My senses were assaulted. Smells like tea tree oil. Feels like conditioner or lotion.  I can’t understand how the delivery person a) didn’t smell that mess when they shoved the pkg in b) didn’t see the mess when they shoved it in - tho if they were short I guess that would explain it bc I’m 5’10” & I didn’t see it until the pkg was in my hands. The locker was up high & dark, but I could smell it the minute I walked into the hub locker room. I happen to be extremely allergic to tea tree oil.  It’s made from mellaleuca trees which grow all over southwest Florida where I was raised.  Tho native to Australia they were used to help drain the swamps of Florida generations ago bc they soak up so much water.  It has a very distinct smell & unfortunately is frequently used as a “carrier oil” for other oils & body lotions,  shampoos, conditioners, etc., so I have to be hyper-vigilant to avoid exposure.  Instead- Last night I got to suck down Benadryl & pray my throat didn’t close while keeping my epi-pens handy.  The liquid went through the holes & onto the snowsuit as you can clearly see in the pictures.  So I guess the suit is waterproof.  Looks true to size.  Elastic appears stretchy.  I’m super annoyed that this arrived in this condition & could have easily been avoided by amazon properly wrapping it to avoid the elements whatever they may be.', 
                    'images': [{'attachment_type': 'IMAGE', 'large_image_url': 'https://m.media-amazon.com/images/I/710WrjJi+hL._SL1600_.jpg', 'medium_image_url': 'https://m.media-amazon.com/images/I/710WrjJi+hL._SL800_.jpg', 'small_image_url': 'https://m.media-amazon.com/images/I/710WrjJi+hL._SL256_.jpg'}, 
                               {'attachment_type': 'IMAGE', 'large_image_url': 'https://m.media-amazon.com/images/I/712+yNg8COL._SL1600_.jpg', 'medium_image_url': 'https://m.media-amazon.com/images/I/712+yNg8COL._SL800_.jpg', 'small_image_url': 'https://m.media-amazon.com/images/I/712+yNg8COL._SL256_.jpg'}, 
                               {'attachment_type': 'IMAGE', 'large_image_url': 'https://m.media-amazon.com/images/I/7132ByALa+L._SL1600_.jpg', 'medium_image_url': 'https://m.media-amazon.com/images/I/7132ByALa+L._SL800_.jpg', 'small_image_url': 'https://m.media-amazon.com/images/I/7132ByALa+L._SL256_.jpg'}, 
                               {'attachment_type': 'IMAGE', 'large_image_url': 'https://m.media-amazon.com/images/I/718OTnxL+CL._SL1600_.jpg', 'medium_image_url': 'https://m.media-amazon.com/images/I/718OTnxL+CL._SL800_.jpg', 'small_image_url': 'https://m.media-amazon.com/images/I/718OTnxL+CL._SL256_.jpg'}, 
                               {'attachment_type': 'IMAGE', 'large_image_url': 'https://m.media-amazon.com/images/I/71I6b8DyazL._SL1600_.jpg', 'medium_image_url': 'https://m.media-amazon.com/images/I/71I6b8DyazL._SL800_.jpg', 'small_image_url': 'https://m.media-amazon.com/images/I/71I6b8DyazL._SL256_.jpg'}, 
                               {'attachment_type': 'IMAGE', 'large_image_url': 'https://m.media-amazon.com/images/I/71v4KKrIXuL._SL1600_.jpg', 'medium_image_url': 'https://m.media-amazon.com/images/I/71v4KKrIXuL._SL800_.jpg', 'small_image_url': 'https://m.media-amazon.com/images/I/71v4KKrIXuL._SL256_.jpg'}], 
                    'asin': 'B096S6LZV4', 'parent_asin': 'B073C4Q7W8', 'user_id': 'AFKZENTNBQ7A7V7UXW5JJI6UGRYQ', 'timestamp': 1677938767351, 'helpful_vote': 0, 'verified_purchase': True}]

#for i in tqdm(range(len(meta_dataset)), total = len(meta_dataset)):
#    meta_dataset[i]['review'] = []
#    for j in tqdm(range(len(dataset['full'])), total = len(dataset['full'])):
#        if dataset['full'][j]['parent_asin'] == meta_dataset[i]['parent_asin']:
#            meta_dataset[i]['review'].append(dataset['full'][j])

# %%
# parent_asin을 기준으로 review 데이터를 그룹화하는 딕셔너리 생성
review_dict = {}
for review in tqdm(dataset['full'], desc="Processing dataset"):
    parent_asin = review['parent_asin']
    if parent_asin in review_dict:
        review_dict[parent_asin].append(review)
    else:
        review_dict[parent_asin] = [review]

# meta_dataset을 순회하면서 각 항목에 대한 review 데이터 추가
for item in tqdm(meta_dataset, desc="Processing meta_dataset"):

    parent_asin = item['parent_asin']
    if parent_asin in review_dict:
        item['review'] = review_dict[parent_asin]
    else:
        item['review'] = []
# Out:
# Processing dataset: 100%|██████████| 2/2 [00:00<00:00, 34379.54it/s]
# Processing meta_dataset: 100%|██████████| 2/2 [00:00<00:00, 27060.03it/s]

# %%
list2 = []
k = 0
for item in review_dict.items():
    list2.append(item)
    k += 1
    
    if k == 30:
        break

# %%
list2
# Out:
# [('B073C4Q7W8',
#   [{'rating': 3.0,
#     'title': 'Arrived Damaged : liquid in hub locker!',
#     'text': 'Unfortunately Amazon in their wisdom (cough, cough) decided to ship the snowsuit in a vinyl bag with holes in it!  There was no other bag to protect the snowsuit inside vinyl bag with all the holes.  This is what happened:  Arrived in hub locker. It was the very top locker. Opened it & pulled the pkg out getting a very wet & nasty surprise at the same time. My senses were assaulted. Smells like tea tree oil. Feels like conditioner or lotion.  I can’t understand how the delivery person a) didn’t smell that mess when they shoved the pkg in b) didn’t see the mess when they shoved it in - tho if they were short I guess that would explain it bc I’m 5’10” & I didn’t see it until the pkg was in my hands. The locker was up high & dark, but I could smell it the minute I walked into the hub locker room. I happen to be extremely allergic to tea tree oil.  It’s made from mellaleuca trees which grow all over southwest Florida where I was raised.  Tho native to Australia they were used to help drain the swamps of Florida generations ago bc they soak up so much water.  It has a very distinct smell & unfortunately is frequently used as a “carrier oil” for other oils & body lotions,  shampoos, conditioners, etc., so I have to be hyper-vigilant to avoid exposure.  Instead- Last night I got to suck down Benadryl & pray my throat didn’t close while keeping my epi-pens handy.  The liquid went through the holes & onto the snowsuit as you can clearly see in the pictures.  So I guess the suit is waterproof.  Looks true to size.  Elastic appears stretchy.  I’m super annoyed that this arrived in this condition & could have easily been avoided by amazon properly wrapping it to avoid the elements whatever they may be.',
#     'images': [{'attachment_type': 'IMAGE',
#       'large_image_url': 'https://m.media-amazon.com/images/I/710WrjJi+hL._SL1600_.jpg',
#       'medium_image_url': 'https://m.media-amazon.com/images/I/710WrjJi+hL._SL800_.jpg',
#       'small_image_url': 'https://m.media-amazon.com/images/I/710WrjJi+hL._SL256_.jpg'},
#      {'attachment_type': 'IMAGE',
#       'large_image_url': 'https://m.media-amazon.com/images/I/712+yNg8COL._SL1600_.jpg',
#       'medium_image_url': 'https://m.media-amazon.com/images/I/712+yNg8COL._SL800_.jpg',
#       'small_image_url': 'https://m.media-amazon.com/images/I/712+yNg8COL._SL256_.jpg'},
#      {'attachment_type': 'IMAGE',
#       'large_image_url': 'https://m.media-amazon.com/images/I/7132ByALa+L._SL1600_.jpg',
#       'medium_image_url': 'https://m.media-amazon.com/images/I/7132ByALa+L._SL800_.jpg',
#       'small_image_url': 'https://m.media-amazon.com/images/I/7132ByALa+L._SL256_.jpg'},
#      {'attachment_type': 'IMAGE',
#       'large_image_url': 'https://m.media-amazon.com/images/I/718OTnxL+CL._SL1600_.jpg',
#       'medium_image_url': 'https://m.media-amazon.com/images/I/718OTnxL+CL._SL800_.jpg',
#       'small_image_url': 'https://m.media-amazon.com/images/I/718OTnxL+CL._SL256_.jpg'},
#      {'attachment_type': 'IMAGE',
#       'large_image_url': 'https://m.media-amazon.com/images/I/71I6b8DyazL._SL1600_.jpg',
#       'medium_image_url': 'https://m.media-amazon.com/images/I/71I6b8DyazL._SL800_.jpg',
#       'small_image_url': 'https://m.media-amazon.com/images/I/71I6b8DyazL._SL256_.jpg'},
#      {'attachment_type': 'IMAGE',
#       'large_image_url': 'https://m.media-amazon.com/images/I/71v4KKrIXuL._SL1600_.jpg',
#       'medium_image_url': 'https://m.media-amazon.com/images/I/71v4KKrIXuL._SL800_.jpg',
#       'small_image_url': 'https://m.media-amazon.com/images/I/71v4KKrIXuL._SL256_.jpg'}],
#     'asin': 'B096S6LZV4',
#     'parent_asin': 'B073C4Q7W8',
#     'user_id': 'AFKZENTNBQ7A7V7UXW5JJI6UGRYQ',
#     'timestamp': 1677938767351,
#     'helpful_vote': 0,
#     'verified_purchase': True},
#    {'rating': 2.0,
#     'title': 'test2',
#     'text': 'Unfortunately Amazon in their wisdom (cough, cough) decided to ship the snowsuit in a vinyl bag with holes in it!  There was no other bag to protect the snowsuit inside vinyl bag with all the holes.  This is what happened:  Arrived in hub locker. It was the very top locker. Opened it & pulled the pkg out getting a very wet & nasty surprise at the same time. My senses were assaulted. Smells like tea tree oil. Feels like conditioner or lotion.  I can’t understand how the delivery person a) didn’t smell that mess when they shoved the pkg in b) didn’t see the mess when they shoved it in - tho if they were short I guess that would explain it bc I’m 5’10” & I didn’t see it until the pkg was in my hands. The locker was up high & dark, but I could smell it the minute I walked into the hub locker room. I happen to be extremely allergic to tea tree oil.  It’s made from mellaleuca trees which grow all over southwest Florida where I was raised.  Tho native to Australia they were used to help drain the swamps of Florida generations ago bc they soak up so much water.  It has a very distinct smell & unfortunately is frequently used as a “carrier oil” for other oils & body lotions,  shampoos, conditioners, etc., so I have to be hyper-vigilant to avoid exposure.  Instead- Last night I got to suck down Benadryl & pray my throat didn’t close while keeping my epi-pens handy.  The liquid went through the holes & onto the snowsuit as you can clearly see in the pictures.  So I guess the suit is waterproof.  Looks true to size.  Elastic appears stretchy.  I’m super annoyed that this arrived in this condition & could have easily been avoided by amazon properly wrapping it to avoid the elements whatever they may be.',
#     'images': [{'attachment_type': 'IMAGE',
#       'large_image_url': 'https://m.media-amazon.com/images/I/710WrjJi+hL._SL1600_.jpg',
#       'medium_image_url': 'https://m.media-amazon.com/images/I/710WrjJi+hL._SL800_.jpg',
#       'small_image_url': 'https://m.media-amazon.com/images/I/710WrjJi+hL._SL256_.jpg'},
#      {'attachment_type': 'IMAGE',
#       'large_image_url': 'https://m.media-amazon.com/images/I/712+yNg8COL._SL1600_.jpg',
#       'medium_image_url': 'https://m.media-amazon.com/images/I/712+yNg8COL._SL800_.jpg',
#       'small_image_url': 'https://m.media-amazon.com/images/I/712+yNg8COL._SL256_.jpg'},
#      {'attachment_type': 'IMAGE',
#       'large_image_url': 'https://m.media-amazon.com/images/I/7132ByALa+L._SL1600_.jpg',
#       'medium_image_url': 'https://m.media-amazon.com/images/I/7132ByALa+L._SL800_.jpg',
#       'small_image_url': 'https://m.media-amazon.com/images/I/7132ByALa+L._SL256_.jpg'},
#      {'attachment_type': 'IMAGE',
#       'large_image_url': 'https://m.media-amazon.com/images/I/718OTnxL+CL._SL1600_.jpg',
#       'medium_image_url': 'https://m.media-amazon.com/images/I/718OTnxL+CL._SL800_.jpg',
#       'small_image_url': 'https://m.media-amazon.com/images/I/718OTnxL+CL._SL256_.jpg'},
#      {'attachment_type': 'IMAGE',
#       'large_image_url': 'https://m.media-amazon.com/images/I/71I6b8DyazL._SL1600_.jpg',
#       'medium_image_url': 'https://m.media-amazon.com/images/I/71I6b8DyazL._SL800_.jpg',
#       'small_image_url': 'https://m.media-amazon.com/images/I/71I6b8DyazL._SL256_.jpg'},
#      {'attachment_type': 'IMAGE',
#       'large_image_url': 'https://m.media-amazon.com/images/I/71v4KKrIXuL._SL1600_.jpg',
#       'medium_image_url': 'https://m.media-amazon.com/images/I/71v4KKrIXuL._SL800_.jpg',
#       'small_image_url': 'https://m.media-amazon.com/images/I/71v4KKrIXuL._SL256_.jpg'}],
#     'asin': 'B096S6LZV4',
#     'parent_asin': 'B073C4Q7W8',
#     'user_id': 'AFKZENTNBQ7A7V7UXW5JJI6UGRYQ',
#     'timestamp': 1677938767351,
#     'helpful_vote': 0,
#     'verified_purchase': True}])]

# %%
review_dict
import json
file_name = 'hi.json'
with open(file_name, "w") as f:
    json.dump(review_dict, f)

# %%
import json

#file_name = "my_data.json"
#
## Write the list to a JSON file
#with open(file_name, "w") as f:
#    json.dump(meta_dataset, f)

# %%
file_name = "review.json"
with open(file_name, "r") as f:
    review_dict = json.load(f)

# %%
len(review_dict)
# Out:
# 4792357

# %%
review_dict_test = review_dict[:5]
print(review_dict_test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/67/k4ct0mwx49j46bz5qfxg28_m0000gn/T/ipykernel_3068/978979264.py in <module>
# ----> 1 review_dict_test = review_dict[:5]
#       2 print(review_dict_test)
#
# TypeError: unhashable type: 'slice'

# %%
file_name = "sample.json"
with open(file_name, "r") as f:
    review_dict_test = json.load(f)

# %%
# product에 대한 리뷰 이미지 개수 확인


def count_img(reviews):

    img_user = 0 # 이미지를 올린 유저의 수
    img_cnt = 0 # product 당 리뷰 이미지 수
        
    for review in reviews:
        if review['images']:
            img_user += 1
            img_cnt += len(review['images'])
            
    return img_user, img_cnt
    
review_cnt_dict = {}

for item in review_dict.items():
    
    stop = 0
    
    parent_asin = item[0] # product ID
    img_user, img_cnt = count_img(item[1])
    
    review_cnt_dict[parent_asin] = {'total_review_cnt' : len(item[1]), 
                                          'img_user': img_user,
                                          'img_cnt': img_cnt}
    
    stop += 1
    if stop == 3:
        break

# %%
import json
file_name = 'review_img_cnt.json'
with open(file_name, "w") as f:
    json.dump(review_cnt_dict, f)

# %%
import json
file_name = "review_img_cnt.json"
with open(file_name, "r") as f:
    review_cnt_dict = json.load(f)

# %%
import pandas as pd

df = pd.DataFrame(review_cnt_dict)
df
# Out:
#                   B09NSZ5QMF  B08NGL3X17  B07RGM3DYC  B07BWS4CSM  B09GY6SG2C  \
# total_review_cnt         248         381         299        1167          52
# img_user                  41          15          40          31           1
# img_cnt                   67          27          82          55           1
#
#                   B07HJ84J9M  B01DDC83C8  B0BNP511CS  B01KY0E8TO  B07V6PKCCG  \
# total_review_cnt         680         830         471         146        1528
# img_user                  64         251          30           2          38
# img_cnt                   87         375          45           2          64
#
#                   ...  B07BQG1X8H  B07XMBHFXG  B07ZDP76J4  B07TS8ZCTJ  \
# total_review_cnt  ...           1           1           1           1
# img_user          ...           0           0           0           0
# img_cnt           ...           0           0           0           0
#
#                   B0B8SR8XJ5  B008KSL1CK  B0B77DSP6Y  B08R3KNXMR  B00AMAFE40  \
# total_review_cnt           1           1           1           1           1
# img_user                   0           0           0           0           0
# img_cnt                    0           0           0           0           0
#
#                   B09JVQT6C3
# total_review_cnt           1
# img_user                   0
# img_cnt                    0
#
# [3 rows x 4792357 columns]

# %%
df = df.T

# %%
df.describe().to_csv("cnt_describe.csv")

# %%
df[df['img_user'] != 0].describe().to_csv("cnt_describe_only_img.csv")

# %%
# 5장이 넘는 이미지를 가진 리뷰가 몇개 있는 지 확인
len(df[(df['img_cnt'] > 5) & (df['img_user'] > 1)])
# Out:
# 110914

# %%
df[(df['img_cnt'] > 5) & (df['img_user'] > 1)].describe().to_csv("img_cnt_more_5.csv")

# %%
# save target data
index_list = df[(df['img_cnt'] > 5) & (df['img_user'] > 1)].index.tolist()
index_list
# Out:
# ['B09NSZ5QMF',
#  'B08NGL3X17',
#  'B07RGM3DYC',
#  'B07BWS4CSM',
#  'B07HJ84J9M',
#  'B01DDC83C8',
#  'B0BNP511CS',
#  'B07V6PKCCG',
#  'B07L6QT33F',
#  'B009RTBRVG',
#  'B07TVHSDMQ',
#  'B0773MFW9C',
#  'B013R5TGMM',
#  'B0BXC3M958',
#  'B001UHMUXC',
#  'B0098X5DAM',
#  'B08K31FCDT',
#  'B0BGJ85RYM',
#  'B0943Y5LJ1',
#  'B07PDP14YY',
#  'B08R8W8GP9',
#  'B0B51SHVKW',
#  'B088F8PM6L',
#  'B09871KL8Z',
#  'B07DB5HGQB',
#  'B01GZP4SRY',
#  'B006SRT01E',
#  'B016YWH0RS',
#  'B0925BQY1H',
#  'B08P3YBW2V',
#  'B07QPPXS2X',
#  'B09P66ZLDX',
#  'B09Q7G1MMW',
#  'B09Q7D5NZW',
#  'B00IP8QFNK',
#  'B0BRX8TCWS',
#  'B0C1TDJ9HZ',
#  'B0BRGXK97Q',
#  'B01KORWZBU',
#  'B085RX192V',
#  'B01HP7L6QC',
#  'B07GWQ8BG1',
#  'B07WP1VDG9',
#  'B08TK24632',
#  'B0714D5LNJ',
#  'B09WBFZRWD',
#  'B00NQYTXXW',
#  'B0BP19WZ3T',
#  'B07PG33SK5',
#  'B0B9ZYDDZ1',
#  'B0BYT41CVB',
#  'B0BBSM8SSR',
#  'B0BH4XV9JC',
#  'B09ZL4W5T8',
#  'B083G34TB8',
#  'B075B41Y9Z',
#  'B01N9VHLUB',
#  'B01D8MNCPG',
#  'B0BB11SLBC',
#  'B00Q5DT37W',
#  'B08CF316KG',
#  'B0C3YJMRRD',
#  'B07HHVNZ9W',
#  'B00VMGV29Y',
#  'B08XVRZB7N',
#  'B0713TKXLT',
#  'B0B2RL44XD',
#  'B091FRBPKQ',
#  'B0BG25LHV2',
#  'B09VN5J1YZ',
#  'B07WMZ1Y95',
#  'B08P4KTHZV',
#  'B097QZ1RGR',
#  'B0C4DGQZK2',
#  'B09NWG7D65',
#  'B0BMZD27Q1',
#  'B09CDXCV76',
#  'B0817PMCNH',
#  'B0866HHMQZ',
#  'B074Z6264S',
#  'B0982FRC3T',
#  'B089368ZCX',
#  'B07C1Z2JLC',
#  'B07V33GN1Q',
#  'B01IB0KNFC',
#  'B0BJ52SNMY',
#  'B079N49KN2',
#  'B07FDWZBPK',
#  'B07DRRV34R',
#  'B01MT1L2P7',
#  'B0BWJQBN27',
#  'B074N8H5NP',
#  'B077GQV9V2',
#  'B09175BYM6',
#  'B09HSVSDCH',
#  'B0C3WLLYW9',
#  'B09M6XCMHJ',
#  'B07PF1T3PN',
#  'B09Y2TYH71',
#  'B07S22BQCK',
#  'B0C55V2Y3Q',
#  'B09BPW6HPX',
#  'B08S398SK5',
#  'B094W6VZGC',
#  'B08S382SDX',
#  'B096TL6GP9',
#  'B0714CRNL5',
#  'B0B62QD6RK',
#  'B08F8KW9V9',
#  'B07MQ4217D',
#  'B07D34BF9S',
#  'B07KCN4G6T',
#  'B000XR4OC0',
#  'B0BQVWJRMR',
#  'B073XLK7FF',
#  'B074CSSC8S',
#  'B0BYC79F57',
#  'B08QRQCL63',
#  'B07BJL7L62',
#  'B01MTDK0I0',
#  'B0859KW5NV',
#  'B0779VRNK6',
#  'B085L8HS4T',
#  'B082771XLV',
#  'B097WZT5F8',
#  'B07H5G8D7R',
#  'B09SGTVP68',
#  'B07PLZQ6YV',
#  'B095W5WHNC',
#  'B07JZ5Z926',
#  'B09WL6LJ4Z',
#  'B09M5ZN97B',
#  'B074TWL5HV',
#  'B09MHTR424',
#  'B01MXEZE6O',
#  'B09MHMFKJQ',
#  'B07X1G5PBB',
#  'B07C9RJB7J',
#  'B00A26LUUQ',
#  'B099NF11VV',
#  'B017KYHIB2',
#  'B0C62QP4L8',
#  'B01MT8NEMQ',
#  'B07MBFBVX4',
#  'B07C8M11PK',
#  'B01DDVFT8U',
#  'B000VK6QTI',
#  'B09PBQN578',
#  'B017BFAPGA',
#  'B07CDP44DB',
#  'B01G1LHC0C',
#  'B00EXFC042',
#  'B075JDMV12',
#  'B07LCG7SQM',
#  'B07SXH69DR',
#  'B078P1K2M7',
#  'B099ZKM2XZ',
#  'B07HRDFDHB',
#  'B0BV29CJLM',
#  'B084VL8ZYJ',
#  'B08X8MW636',
#  'B09N16L76J',
#  'B0C15FHBQ2',
#  'B09HT4YFZW',
#  'B0BLXPNPQV',
#  'B0B4JK43ZP',
#  'B0813X1RBR',
#  'B073RHZ35F',
#  'B0C3B6HZGC',
#  'B0BLTQDRT5',
#  'B07T7RFKSR',
#  'B098L46KLZ',
#  'B06XPDWKGZ',
#  'B01K1TJRM6',
#  'B0BV3C27HW',
#  'B07CNR7DS8',
#  'B085YVFQLR',
#  'B010GNGBJ4',
#  'B09DTQXJDP',
#  'B07F57ZSTD',
#  'B07BVB6W9B',
#  'B07QTVKNNQ',
#  'B0B2BCZR6D',
#  'B0C4TNBGVG',
#  'B0C3YBXFYM',
#  'B08JSDVT61',
#  'B005MXHQXO',
#  'B082CXRB4F',
#  'B07TDTVD5C',
#  'B0C2Q3NFQ1',
#  'B0BB6BDP5F',
#  'B07D3P1B7F',
#  'B0B2TZDV7Y',
#  'B071CVH7VW',
#  'B09NPJRNYQ',
#  'B01KSLDRQO',
#  'B00T6LHERQ',
#  'B0C2W4FFBW',
#  'B07W5VKVTD',
#  'B09MS24623',
#  'B08VK9S8BL',
#  'B08YD9L5BT',
#  'B00V5JSA6G',
#  'B08FM5686D',
#  'B07HWS68BX',
#  'B072135YQN',
#  'B07CKYHSP6',
#  'B098F8FLYJ',
#  'B0C4STXW3B',
#  'B08H38QX2Y',
#  'B092VLGG3Y',
#  'B0BN9DY5FV',
#  'B0BV8F1H41',
#  'B07BXQHQC6',
#  'B098L6JFWY',
#  'B0936QP9RG',
#  'B005FYNXBY',
#  'B078RJP263',
#  'B0BWQKLZ71',
#  'B00JULWOFE',
#  'B083XHFY4V',
#  'B0B72B538P',
#  'B07VKN1LYB',
#  'B07V46T4QL',
#  'B01M0B3MH7',
#  'B07G55375D',
#  'B07938P1FC',
#  'B07R1X5B9L',
#  'B07BQNGXLN',
#  'B00LPKA7PC',
#  'B082F8JX3Z',
#  'B0BPMQY64S',
#  'B08ZVF3LJT',
#  'B0B4BRW7JT',
#  'B07DC46FT3',
#  'B0C2WP4RVN',
#  'B086Z7CFJ7',
#  'B019EG644Q',
#  'B084GFBZ7Y',
#  'B09HGJY9H2',
#  'B07K1XPXTT',
#  'B08791NBYT',
#  'B07C316SYF',
#  'B092VJNVPB',
#  'B006OY37V0',
#  'B081XZT5FX',
#  'B091JK38RZ',
#  'B07X4BLRMY',
#  'B0B4W4ZQR6',
#  'B09XJZNRFF',
#  'B0B69WF5ZX',
#  'B07TT8JMX5',
#  'B016YKHXL8',
#  'B01NCWA797',
#  'B0BSX47TRY',
#  'B0B2DWXCFR',
#  'B08H82ZCKL',
#  'B08RNMYKZW',
#  'B0BY7L97MC',
#  'B07X9V6HZX',
#  'B077F8FD9K',
#  'B07WX1YYPB',
#  'B09QT3ZDGK',
#  'B0C5S65B9S',
#  'B089WQRYM2',
#  'B09GKJYJKJ',
#  'B07KF857CW',
#  'B08MZJ4BPB',
#  'B09Z9G8PVL',
#  'B07CHSX68N',
#  'B07NBTJJ6K',
#  'B08P4SSFX4',
#  'B07BJB844X',
#  'B07G7JHXJY',
#  'B099F6GD6R',
#  'B0041G5SEC',
#  'B07M9JDPCL',
#  'B08CZQ7H3Y',
#  'B07HNVQJXN',
#  'B0969853Z4',
#  'B075WNYJGF',
#  'B0B5V6TKHM',
#  'B08N4GC5KC',
#  'B09F6X6K8F',
#  'B07YV6GJWR',
#  'B09GL2H8KM',
#  'B09Y8WLD47',
#  'B08SLNX6NR',
#  'B0BH1ZBZ4N',
#  'B0BQYY4ZCG',
#  'B087TS99RH',
#  'B098JB1668',
#  'B08Y8HNKFT',
#  'B08ZY6WHDX',
#  'B08TQF757R',
#  'B08XYNW9LC',
#  'B08Y8845XG',
#  'B0B7JQYKN1',
#  'B002E3KYWA',
#  'B07XGCMY6X',
#  'B00WQ4DIYI',
#  'B07S5H9R7X',
#  'B0814841T8',
#  'B0937LT6FV',
#  'B0BG6LR7GH',
#  'B07K28YG2Q',
#  'B07VFPS68P',
#  'B07CP985M6',
#  'B07RNJBQRD',
#  'B07DT3B2Z8',
#  'B0BXFF6TCW',
#  'B0BK77PYFS',
#  'B07D618TP2',
#  'B0BFWJBYBP',
#  'B0184O3B86',
#  'B07RLCJKQR',
#  'B06XDHRDLD',
#  'B09JYS1SB6',
#  'B076KWSLP4',
#  'B00C6WQ0V8',
#  'B0B1W5LGZD',
#  'B0C4KFJP83',
#  'B00AK8C4QA',
#  'B07VNNTKML',
#  'B019ZZVO28',
#  'B01HF9ZN7I',
#  'B0B6FXX7Q3',
#  'B07TWJC9JZ',
#  'B0B1JG67GY',
#  'B0BT8T2FQ3',
#  'B06X9H5JXT',
#  'B00P6VYQSK',
#  'B002YQ2GIW',
#  'B0C3CW51PR',
#  'B010N4J5XU',
#  'B08G4XQ89V',
#  'B091T39732',
#  'B07GTN9YMQ',
#  'B07S21RQKK',
#  'B0B6478C9Q',
#  'B07XGRG4JP',
#  'B07CWRPW3N',
#  'B09ZQQG855',
#  'B0BG36RDF4',
#  'B0BQVRWY7D',
#  'B09GN15CYZ',
#  'B07DZTNJ1Y',
#  'B0B979WNHF',
#  'B07GK13BPW',
#  'B08XNJ19PC',
#  'B0C54B89HH',
#  'B005GI8UZ8',
#  'B0084AVW7I',
#  'B0BPGGV1K3',
#  'B0BS9R2BN3',
#  'B0BXQJ8Q1F',
#  'B0BMM19KXL',
#  'B0BZDLXKTS',
#  'B0096GO29E',
#  'B0C1HR148K',
#  'B0BRN12XZD',
#  'B08KYFL9GY',
#  'B08Q3ZTHQ4',
#  'B008HRV930',
#  'B07BHVLRF2',
#  'B07BFT5Z8Z',
#  'B07CMFM5ZS',
#  'B09SHGYJD2',
#  'B094P7MP7R',
#  'B00YPNZKUS',
#  'B073G6Q2NV',
#  'B07S6RZHTX',
#  'B0C1VN8L36',
#  'B08P3FJ73R',
#  'B07PZY9YVG',
#  'B01FQTSSQM',
#  'B08Y8V1CBK',
#  'B07Y5358BS',
#  'B08F9F84H4',
#  'B07SXBDCW9',
#  'B07RV67ZC6',
#  'B07D16BLH2',
#  'B005FUKOWO',
#  'B075NDQP3Q',
#  'B074KJ49F2',
#  'B07PYB8F1G',
#  'B0BGS9ZL6R',
#  'B00284ADPS',
#  'B07JHX3RJ6',
#  'B09VRJ2KM7',
#  'B0B7XTJB54',
#  'B08922H1WD',
#  'B075SBQRXG',
#  'B091F1PL4X',
#  'B097JVMDG9',
#  'B0BN1YK5ND',
#  'B016D7C3G2',
#  'B078WH536F',
#  'B08CRQQG76',
#  'B013254YQ0',
#  'B08HD8MSKR',
#  'B09M6RG7YC',
#  'B0C28DJ4SD',
#  'B09M8PMH3G',
#  'B0BP1S2W9M',
#  'B0BRV3ZBSP',
#  'B0B5R6H9Z4',
#  'B0B96MPVP8',
#  'B0BCDF1M8Y',
#  'B0967JRJKS',
#  'B08GQ5WJT9',
#  'B08VJF728K',
#  'B08FCH9QZ1',
#  'B07W6TDBBH',
#  'B08QZ9P5SW',
#  'B088FBDQ9B',
#  'B08L4DQ1DM',
#  'B097Q8JJQ8',
#  'B08L63L3TD',
#  'B08GYC7FTT',
#  'B08DHK3S5M',
#  'B08CSBX7VS',
#  'B08LPBCQJ2',
#  'B08761GW7K',
#  'B08F723WNJ',
#  'B09DPJ7989',
#  'B0BVLXXT96',
#  'B087R73HWP',
#  'B089SXFBXW',
#  'B088QJWHDT',
#  'B0C5FCSHQS',
#  'B07TLSLDYG',
#  'B09HLD236K',
#  'B084HGJYDC',
#  'B085VRTVRN',
#  'B08DS4X4RB',
#  'B07WV1SGHG',
#  'B0C4SXCVMF',
#  'B07VX1F6K3',
#  'B07PLHVRJR',
#  'B07X9M21LY',
#  'B07GYC5ZWR',
#  'B07TLWPZW7',
#  'B07S91K5H9',
#  'B0869ZBCHJ',
#  'B07STTNTCZ',
#  'B095J99RQR',
#  'B07RFH3D9T',
#  'B07R2995QF',
#  'B07N19QTG3',
#  'B07Q364XRW',
#  'B07QRFTM75',
#  'B07QTXFT53',
#  'B0C6R93HH4',
#  'B07VL1TTHT',
#  'B0BR145W6Q',
#  'B07GSDXP7Y',
#  'B09XMYBG59',
#  'B076PX49KJ',
#  'B077397LSH',
#  'B07C8GV2T7',
#  'B07CNKGHWR',
#  'B01FENJHHY',
#  'B0779LPBCL',
#  'B002ZNZJII',
#  'B00HVQUFRY',
#  'B07X5V23ZN',
#  'B07ZR2ZYP9',
#  'B07NTVDNZG',
#  'B06XVJRT9S',
#  'B0B123CVR9',
#  'B0BC4KN2YW',
#  'B0C4G3VQ9W',
#  'B075P15Q1Y',
#  'B0C4LT6VYD',
#  'B08LJ59ZJ8',
#  'B09329K4TL',
#  'B00A8FA0H0',
#  'B07N2QCSQ4',
#  'B01LZMPGLF',
#  'B00PXSBAJO',
#  'B09DPVPZHY',
#  'B07Y1DRP4K',
#  'B08PYX1N7R',
#  'B07WRXPLPF',
#  'B01I21CI30',
#  'B0BG3B8BKZ',
#  'B00U3792OU',
#  'B07P7YR9H8',
#  'B07DG1R58G',
#  'B09STV6WLZ',
#  'B09BFFJNR7',
#  'B07N14HNKL',
#  'B01MCY01WK',
#  'B0842C6LXJ',
#  'B0993416VS',
#  'B09SZ9FF13',
#  'B0875LLBZ4',
#  'B08FRHS22T',
#  'B09G5NMVCK',
#  'B0C64L9CJV',
#  'B0C54KM5HX',
#  'B08X2X83DW',
#  'B0BZCR2Z1C',
#  'B07FX4KZH5',
#  'B002Q1P12S',
#  'B0C4TLH35V',
#  'B09M7SY5KM',
#  'B07VN24Z91',
#  'B0C3Y37PSZ',
#  'B017QQTDNA',
#  'B095CF55QB',
#  'B0925XKC7G',
#  'B07HRR9K3Z',
#  'B09TG1R4TK',
#  'B01K8WCSFY',
#  'B07XJZ1B6P',
#  'B08CZ34D75',
#  'B083DMX8ZF',
#  'B01C4VT5NA',
#  'B07QRS749C',
#  'B07Y281FLT',
#  'B07YNZNK76',
#  'B0BPT2DY3P',
#  'B07HXFB88H',
#  'B0B59193TL',
#  'B016OT9D3K',
#  'B0975P4FCT',
#  'B08HVBM998',
#  'B06XJNYKDL',
#  'B0863HZ4DL',
#  'B00T2SSIO6',
#  'B0B68M6BC2',
#  'B07F2FB97F',
#  'B0BHKMWH12',
#  'B0C7CWY3GB',
#  'B08ZKFD4GM',
#  'B07PGJG15G',
#  'B0BW96R1X3',
#  'B07JXTKG5D',
#  'B072MFT44F',
#  'B0988M4JCM',
#  'B091C32M5N',
#  'B0BCWZVD74',
#  'B017BQA9P6',
#  'B0C6834C54',
#  'B07H89L1SW',
#  'B08GFXYPHN',
#  'B07WZ9D4BS',
#  'B07QWS4ZLY',
#  'B07MS91X7Y',
#  'B0B7PVVRZQ',
#  'B096TJWWRM',
#  'B09L4V5P21',
#  'B09RW4L46T',
#  'B071YV88D9',
#  'B08TBJBX49',
#  'B099WLPYXH',
#  'B08L1Q5VCD',
#  'B01881L6QO',
#  'B093PRDFZR',
#  'B079J5B9K6',
#  'B07BM9ZMLN',
#  'B07C72CYMV',
#  'B01D9O4YAU',
#  'B07QQXLYFR',
#  'B0C7YTFZTW',
#  'B0719X659J',
#  'B01N3YS516',
#  'B07XNXJTY3',
#  'B07F2Q7NVW',
#  'B09D44DWF1',
#  'B0C24CD7X5',
#  'B015QOIFLK',
#  'B08NY845M2',
#  'B0C3H839RH',
#  'B003IWYN6O',
#  'B01L86GNYG',
#  'B01MYP1GHC',
#  'B01MQGH5MM',
#  'B07VQ11Q35',
#  'B09QR41C7L',
#  'B097R3L257',
#  'B0779BF96T',
#  'B093QSK3W1',
#  'B00HWP8922',
#  'B086BMHQDQ',
#  'B071JMD8NJ',
#  'B0BVVM8T2N',
#  'B01IBZJA10',
#  'B076C43N4W',
#  'B07BJBYBV3',
#  'B073WPQJTY',
#  'B077HVSYKQ',
#  'B07TVX3KBT',
#  'B0BBG6V6HW',
#  'B09S4LZFRW',
#  'B01DAG6ADG',
#  'B0BG17KS8B',
#  'B087N7WQLC',
#  'B0B2N6HP8H',
#  'B06ZZD5G1R',
#  'B0BZCVF7Y4',
#  'B07RJ852PF',
#  'B071HW9RZB',
#  'B07CNC83PS',
#  'B0B434H4KW',
#  'B0865HNG2S',
#  'B08Z1P3RR3',
#  'B07CJS4D4H',
#  'B0979ZS95M',
#  'B06WW9QYCS',
#  'B07BZZ33R6',
#  'B00TPW7W1E',
#  'B09HZF7TQN',
#  'B01DJ659UM',
#  'B078KQCVQ4',
#  'B07BS3YC9C',
#  'B07B63KFNV',
#  'B09M5NT4NC',
#  'B083VSHRKL',
#  'B0CCX7R8JJ',
#  'B0018OMK82',
#  'B08QZ9ZZDK',
#  'B07568JYPN',
#  'B0076KPIPY',
#  'B0BHVSXL7D',
#  'B07CZGQX9T',
#  'B014IU7GFE',
#  'B006O5HA7G',
#  'B097R4PPYN',
#  'B08B4XRBYR',
#  'B07KPMR9T4',
#  'B09VMHDC5R',
#  'B08D22XC8M',
#  'B0C5M5DFPT',
#  'B07MVCDPGV',
#  'B08R17DTNJ',
#  'B07GRKGV75',
#  'B01HCKITMQ',
#  'B07XCT2ZSY',
#  'B0BC2LBKZD',
#  'B0C2RYDJXC',
#  'B07NVFB41W',
#  'B00B6FGOTO',
#  'B0B17CLLP8',
#  'B07MDN7K6D',
#  'B0BQNYYWDV',
#  'B000VK9ZJG',
#  'B0B2TQQ6Y4',
#  'B07T4WDPGJ',
#  'B076HBFTYR',
#  'B09JD3Q5TD',
#  'B0B99W8RZP',
#  'B084PK3HLK',
#  'B0BZGBK5D2',
#  'B07LGKG14X',
#  'B01N4BU1SJ',
#  'B01N1SKWD0',
#  'B0B5QBRX9P',
#  'B00FFKL0LS',
#  'B01M2CSB8O',
#  'B0C4HBS6TM',
#  'B0C73DSG4D',
#  'B0026MRR1A',
#  'B00413QUHE',
#  'B08PCW52LR',
#  'B0791BH3KD',
#  'B0BWJBG39S',
#  'B01N79F1TO',
#  'B07NQ7N1ZR',
#  'B0738J92C4',
#  'B072XXQD1Y',
#  'B07ZCG6K17',
#  'B078RSHPDP',
#  'B07GBR6W7V',
#  'B0978RW51J',
#  'B0BGG6F3BH',
#  'B0B4ZDMJS3',
#  'B08BJ2NZVG',
#  'B07DWXMJFP',
#  'B09M7CSRJK',
#  'B0C68WVRD1',
#  'B0BHFRL32B',
#  'B0BFV6Y1P2',
#  'B09L7VNT6T',
#  'B0863H2XQZ',
#  'B0BSSKQ9B9',
#  'B0B5B7SBFZ',
#  'B084RN7ZFF',
#  'B07KYHRKVB',
#  'B07Y9DC34B',
#  'B07N1JPR27',
#  'B0B4KG2GQ3',
#  'B083NVSG7W',
#  'B07RRZJS99',
#  'B01K1TSP6U',
#  'B07SMB7J9G',
#  'B01L8IEUIK',
#  'B088LBRZ27',
#  'B0BGQMS357',
#  'B088KDQ9KC',
#  'B08R61KD6Q',
#  'B08VGMCM4B',
#  'B0885QWFLK',
#  'B00GGC0NX0',
#  'B09YKB6LQ6',
#  'B09Y3V1P78',
#  'B07TFFCM31',
#  'B098PX4ZKM',
#  'B07H32GW6L',
#  'B0886B31N5',
#  'B08XVM4KR9',
#  'B093D8GSMS',
#  'B08CZN1JPN',
#  'B096ZX5LBY',
#  'B0BGZ2LYXY',
#  'B08FM96L5N',
#  'B08QRRZ5GF',
#  'B07KPL192B',
#  'B07KF1TZM2',
#  'B072WC6Y1G',
#  'B08PPX6DYB',
#  'B079SKHJ9D',
#  'B09HQC2MZF',
#  'B0B9CFWPLV',
#  'B078X9B85N',
#  'B0C4VLWWYY',
#  'B087FCFKLK',
#  'B09QQBLC99',
#  'B07BNCBMT1',
#  'B07KXR5LG1',
#  'B0BDGH4SPR',
#  'B07QR51JRB',
#  'B07DN9S832',
#  'B09MVY29MY',
#  'B09D9DXF6X',
#  'B07G2B6QCH',
#  'B0989F4SD4',
#  'B09MKXDSXT',
#  'B08P1VVTTC',
#  'B08R5M1229',
#  'B01HIK869Q',
#  'B07JW9Y3MH',
#  'B0BBMJR92W',
#  'B07XB4G4WQ',
#  'B00W6BMZ7W',
#  'B09R9J3RBY',
#  'B085ZMB9B2',
#  'B07RP63BSM',
#  'B08XJVW6QJ',
#  'B0BQQ8KLWX',
#  'B08GPWXNDT',
#  'B0C1GGKR87',
#  'B086ZLDFVJ',
#  'B081ZN2R9K',
#  'B07LFTZ8RH',
#  'B081YPBLHD',
#  'B094J3HNLX',
#  'B075XD9K2V',
#  'B07KF1X4DZ',
#  'B01N3S8KY8',
#  'B07HCWY71J',
#  'B07MW4HTFZ',
#  'B0BDFHVFGW',
#  'B07KKHM2LX',
#  'B07KKFKNDD',
#  'B01BU25GE6',
#  'B09XQRH75T',
#  'B09M6673GT',
#  'B071NRQ3L2',
#  'B08Z9Y2NN3',
#  'B08M375QFK',
#  'B0C5FZ81JP',
#  'B07TX6YBCB',
#  'B0BCYT4T9T',
#  'B00MUKK2HY',
#  'B0B5C6F12J',
#  'B017TGXPO0',
#  'B0BN2F91P8',
#  'B017X5NAQ0',
#  'B01DK0PLEQ',
#  'B09M8F2SRL',
#  'B098JFXZVK',
#  'B01M99L9WW',
#  'B08667X3JN',
#  'B093D4JCJV',
#  'B087FXJX61',
#  'B08R8T3JB9',
#  'B07K1NRRC3',
#  'B0771QQG39',
#  'B09GLSRWBS',
#  'B08QYLJSLN',
#  'B09YYT5KT2',
#  'B09ZCJNVVT',
#  'B07NFBPSCH',
#  'B0BXL182XM',
#  'B0B66LGD55',
#  'B00975EAJ6',
#  'B00VF2F4H6',
#  'B07SPWBCKS',
#  'B07P72HG1R',
#  'B09FNHVV33',
#  'B07XDSF2LL',
#  'B08P67X49C',
#  'B09QTHVDT8',
#  'B01MY80QOV',
#  'B09SCZC92K',
#  'B07RM8NJLF',
#  'B09MVXGLHP',
#  'B077PKG5SP',
#  'B09M7BTH8B',
#  'B0B5KNFFGH',
#  'B075LJDZC4',
#  'B082XY5XJR',
#  'B01IDFBZDO',
#  'B0BLP98TLY',
#  'B0713WZ6VK',
#  'B09JS8T24T',
#  'B088KQFY3Y',
#  'B09XFD75HR',
#  'B07RPBYT4G',
#  'B01GIFMBS4',
#  'B09V1VMXVQ',
#  'B0B9KD494Z',
#  'B07CT89TY3',
#  'B07S8Q2KF6',
#  'B08HCJBVNH',
#  'B09288W59T',
#  'B08SMFWLRP',
#  'B06Y1G39WJ',
#  'B07DHN99F4',
#  'B07H6FV4D4',
#  'B07Y2ZZPQ5',
#  'B07BZ82BY7',
#  'B085N86LP4',
#  'B09L1KF2XF',
#  'B0BPTGYTPD',
#  'B07HMKDM6N',
#  'B00K2ZIAW8',
#  'B07RWQC746',
#  'B07DD71YCN',
#  'B07779QH5H',
#  'B07PNPTHYY',
#  'B071FK3X8F',
#  'B09NDQ9Y8Z',
#  'B086ZXDXKZ',
#  'B08322LK24',
#  'B07D1GD8RK',
#  'B0BJY89K5J',
#  'B0986CNQ2F',
#  'B0915NQ791',
#  'B07KP481PL',
#  'B072LY16MY',
#  'B06WVL47WH',
#  'B09PG7TPRY',
#  'B01IGQT7M6',
#  'B07CQPTK9W',
#  'B08K422T82',
#  'B097TD5KM9',
#  'B0C5FZ9JBL',
#  'B0B77K9DLK',
#  'B01N4WHIM8',
#  'B078HY3VYN',
#  'B07VTZKXV9',
#  'B085FQTC1S',
#  'B0C1NTLNWJ',
#  'B07FN9JZLC',
#  'B081SL6953',
#  'B07HKFJ6WP',
#  'B07F912FLS',
#  'B0C1V15XJC',
#  'B074N82KFZ',
#  'B01ELCZAX4',
#  'B013RJ02EO',
#  'B071X5CDWN',
#  'B0B191XGW2',
#  'B0749CQSWP',
#  'B0BXW1X9F1',
#  'B07BWC61J7',
#  'B07GJJ6WLG',
#  'B072JXYJ16',
#  'B079HJGF1W',
#  'B00UXISOYS',
#  'B078JJ8KTX',
#  'B08LKNWQXV',
#  'B07TNPDXK2',
#  'B0BC8QRD4G',
#  'B0BKC4RSYP',
#  'B079DN76HW',
#  'B09P5Z35P4',
#  'B0B9WHGH6B',
#  'B01AHK2UKU',
#  'B0BJHWY7L3',
#  'B01KBQPSYU',
#  'B001TQBGAW',
#  'B0BWJ1S1VZ',
#  'B016X3TGSY',
#  'B00XLYOQ3O',
#  'B0152R74K4',
#  'B00603WURW',
#  'B08PHR8FYW',
#  'B074CPZ9CQ',
#  'B0856MF831',
#  'B075GSXN4V',
#  'B00LO8G23G',
#  'B07C342D73',
#  'B01LXGLVDR',
#  'B07KVN25VZ',
#  'B00FPQUIDS',
#  'B09949K8R1',
#  'B0B3LFZTLN',
#  'B0776N6525',
#  'B0C4LZY5C1',
#  'B07BTC8YRB',
#  'B01D8OI3ZS',
#  'B07CVZNZBZ',
#  'B07KZWJW4Y',
#  'B011DASVYM',
#  'B013P9ZWUK',
#  'B016212SLO',
#  'B01DOHFJBU',
#  'B00YHMMLXQ',
#  'B072QB7BVQ',
#  'B07CM39VKG',
#  'B079YKGBBJ',
#  'B00L522Z0U',
#  'B001EJNMXS',
#  'B075QMK1DD',
#  'B012W1YKKU',
#  'B00XG0EPS4',
#  'B00IIFFEPU',
#  'B013IXP5U0',
#  'B00F3Z7WO4',
#  'B085RTR1FW',
#  'B0BQF377Z4',
#  'B000DZDT46',
#  'B08LF5XLVZ',
#  'B0066SK0EQ',
#  'B001B9XI3A',
#  'B0C4ZGG1X8',
#  'B0B15FK5J4',
#  'B004EZG9X4',
#  'B085RTKPLF',
#  'B09SJ35H2G',
#  'B00703LLW6',
#  'B0C386JFCG',
#  'B00RKJ2JL2',
#  'B004AOLA1A',
#  'B004UA8ZV2',
#  'B0BV7HT8Y7',
#  'B0C6HF5LBL',
#  'B08926MZWJ',
#  'B08W3C2FZ9',
#  'B0BY7264YR',
#  'B000N8X7Z4',
#  'B0B9XJTZ63',
#  'B07BRBT1XQ',
#  'B09HRQ1G5M',
#  'B0C62MD9JY',
#  'B099X71PQN',
#  'B08NSLZNWQ',
#  'B0991VJMHM',
#  'B0769XD5YC',
#  'B07B6WDQVX',
#  'B0816S8WRP',
#  'B01ITBPXI0',
#  'B07XKRLFDT',
#  'B074JYQSRX',
#  'B09SBBVTN4',
#  'B09C3H7K5S',
#  'B078NRQ5Y9',
#  'B0BS3XGTXN',
#  'B0B4MRJRQX',
#  'B09CDK9TVT',
#  'B07RZJZ775',
#  'B0957FGVHY',
#  'B08TWZ5B92',
#  'B07YHG4PGL',
#  'B08L14LCT7',
#  'B07BZGVBF7',
#  'B09M6P5JJW',
#  'B07F9PK1TN',
#  'B074V7KY4B',
#  'B07Y2BN8G7',
#  'B073CPN8B1',
#  'B07DK7MR4H',
#  'B013WBF9HW',
#  'B07T7DHTNK',
#  'B09VPTJCKB',
#  'B0BZ4BV7NC',
#  'B09F6DP9NV',
#  'B08P3JVDGC',
#  'B0794WWJNL',
#  'B07H9VD8YR',
#  'B07BWD4HYS',
#  'B004LQGMP6',
#  'B01ITBCJGO',
#  'B07H4DNQZ3',
#  'B07FTBJNCL',
#  ...]

# %%
file_name = 'datalist.json'
with open(file_name, "w") as f:
    json.dump(index_list, f)

# %%
df[(df['img_cnt'] > 5) & (df['img_user'] > 1)]['img_cnt'].hist(range = [5, 100])
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df[df['img_user'] != 0]['img_cnt'], range = [0, 25])
plt.show()

# %%
meta_dataset[0]
# Out:
# {'main_category': 'AMAZON FASHION',
#  'title': "BALEAF Women's Long Sleeve Zip Beach Coverup UPF 50+ Sun Protection Hooded Cover Up Shirt Dress with Pockets",
#  'average_rating': 4.2,
#  'rating_number': 422,
#  'features': ['90% Polyester, 10% Spandex',
#   'Zipper closure',
#   'Machine Wash',
#   'Long sleeve sun protection coverups--UPF 50+ blocks the sun from burning',
#   'Zipped v-neckline--fashionable V neck and smooth 1/4 zipper allows to staying place as you like',
#   'Two drop-in side pockets--hold your phone or keys well，no worries of falling out',
#   'Hoodie with non-slip drawcord--Enhancing hooded design is convenient to wrap your face and enough space to put your head and hair easily',
#   'A flattering coverups company you spend all day on the beach，traveling with lovers or busying around house. Recommended For everyday leisure or daily exercise'],
#  'description': [],
#  'price': '31.99',
#  'images': {'hi_res': ['https://m.media-amazon.com/images/I/61KIZjb54AL._AC_UL1500_.jpg',
#    'https://m.media-amazon.com/images/I/61OkTrsW88L._AC_UL1500_.jpg',
#    'https://m.media-amazon.com/images/I/811lbVuVIAL._AC_UL1500_.jpg',
#    'https://m.media-amazon.com/images/I/71wa-UQGlYL._AC_UL1500_.jpg',
#    'https://m.media-amazon.com/images/I/61tspZIpHqL._AC_UL1500_.jpg',
#    'https://m.media-amazon.com/images/I/71oVECB3VYL._AC_UL1500_.jpg'],
#   'large': ['https://m.media-amazon.com/images/I/31zPYU+UkVL._AC_.jpg',
#    'https://m.media-amazon.com/images/I/31LYNX5KQ6L._AC_.jpg',
#    'https://m.media-amazon.com/images/I/51dD8Ga+wQL._AC_.jpg',
#    'https://m.media-amazon.com/images/I/41kM3Cn3ERL._AC_.jpg',
#    'https://m.media-amazon.com/images/I/41ZzITDO+OL._AC_.jpg',
#    'https://m.media-amazon.com/images/I/51jTzfIP3dL._AC_.jpg'],
#   'thumb': ['https://m.media-amazon.com/images/I/31zPYU+UkVL._AC_SR38,50_.jpg',
#    'https://m.media-amazon.com/images/I/31LYNX5KQ6L._AC_SR38,50_.jpg',
#    'https://m.media-amazon.com/images/I/51dD8Ga+wQL._AC_SR38,50_.jpg',
#    'https://m.media-amazon.com/images/I/41kM3Cn3ERL._AC_SR38,50_.jpg',
#    'https://m.media-amazon.com/images/I/41ZzITDO+OL._AC_SR38,50_.jpg',
#    'https://m.media-amazon.com/images/I/51jTzfIP3dL._AC_SR38,50_.jpg'],
#   'variant': ['MAIN', 'PT01', 'PT02', 'PT03', 'PT04', 'PT05']},
#  'videos': {'title': ["Women's UPF 50+ Front Zip Beach Coverups with Pockets",
#    " Women's Swim Cover Up Dress"],
#   'url': ['https://www.amazon.com/vdp/0041f3df9f604577bd982078c9f3fec2?ref=dp_vse_rvc_0',
#    'https://www.amazon.com/vdp/0222bb314b16471a8b43f19080358fdc?ref=dp_vse_rvc_1'],
#   'user_id': ['', '']},
#  'store': 'BALEAF',
#  'categories': ['Clothing, Shoes & Jewelry',
#   'Women',
#   'Clothing',
#   'Swimsuits & Cover Ups',
#   'Cover-Ups'],
#  'details': '{"Department": "womens", "Date First Available": "April 3, 2022"}',
#  'parent_asin': 'B09X1MRDN6',
#  'bought_together': None,
#  'subtitle': None,
#  'author': None}

# %% [markdown]
# # test open image

# %%
from datasets import load_dataset
from tqdm import tqdm

# %%
from urllib import request
import time
from io import BytesIO
from PIL import Image
import json
import matplotlib.pyplot as plt
import os


def load_img(url, time_check = False):
    #url = "https://m.media-amazon.com/images/I/61OkTrsW88L._AC_UL1500_.jpg"

    # time check
    
    
    start = time.time()

    # request.urlopen()
    res = request.urlopen(url).read()

    # 이미지 다운로드 시간 체크
    if time_check == True:
        print(time.time() - start)


    # Image open
    img = Image.open(BytesIO(res))
    
    return img

# %%
large = 'https://images-na.ssl-images-amazon.com/images/I/81ie57zBDHL.jpg'
medium = 'https://images-na.ssl-images-amazon.com/images/I/81ie57zBDHL._SL800_.jpg'
small = 'https://images-na.ssl-images-amazon.com/images/I/81ie57zBDHL._SL256_.jpg'

# %%
print(load_img(large).size)
print(load_img(medium).size)
print(load_img(small).size)
# Out:
# (1154, 1732)
# (533, 800)
# (171, 256)

# %%
load_img(small)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=171x256 at 0x7FC7A0CF7A60>

# %%
import os
import re
import csv
from PIL import Image
import pandas as pd
import torch
import torchvision.models as models
import torchvision.transforms as transforms

# %%
img_list = [os.path.join('sample/images/B09NSZ5QMF', impath) for impath in os.listdir('sample/images/B09NSZ5QMF')]
print(img_list[:3])
# Out:
# ['sample/images/B09NSZ5QMF/B09NSZ5QMF_211_0.jpg', 'sample/images/B09NSZ5QMF/B09NSZ5QMF_0_1.jpg', 'sample/images/B09NSZ5QMF/B09NSZ5QMF_0_0.jpg']

# %%
len(img_list)
# Out:
# 67

# %%
img = Image.open(img_list[0])
print(img.size)
# Out:
# (600, 800)

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x800 at 0x7F9970302AF0>

# %%
image = img.convert("RGB")
print(image)
# Out:
# <PIL.Image.Image image mode=RGB size=600x800 at 0x7F9970302DF0>

# %%
transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )])

# %%
import os
import re
import csv
from PIL import Image
import pandas as pd
import torch
import torchvision.models as models
import torchvision.transforms as transforms

# Define the function to extract the vector
def get_vector(input_image):
    image = input_image.convert("RGB")  # Convert the image to RGB format if not already
    img_t = transform(image)
    batch_t = torch.unsqueeze(img_t, 0)
    my_embedding = torch.zeros([1, 512, 1, 1])

    # Define the hook function to copy the data
    def copy_data(m, i, o):
        my_embedding.copy_(o.data)
    
    # Register the forward hook
    h = layer.register_forward_hook(copy_data)
    model(batch_t)
    h.remove()

    return my_embedding.squeeze().cpu().numpy()

# %%
model = models.resnet18(pretrained=True)
layer = model._modules.get('avgpool')
model.eval()
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )

# %%
vector = get_vector(img)

# %%
vector.shape
# Out:
# (512,)

# %%
import numpy as np

# %%
images = [Image.open(filename).resize((300,300)) for filename in img_list]

image_width, image_height = images[0].size
one_square_size = int(np.ceil(np.sqrt(len(images))))
master_width = (image_width * one_square_size) 
master_height = image_height * one_square_size
spriteimage = Image.new(
    mode='RGBA',
    size=(master_width, master_height),
    color=(0,0,0,0))  # fully transparent
for count, image in enumerate(images):
    div, mod = divmod(count,one_square_size)
    h_loc = image_width*div
    w_loc = image_width*mod    
    spriteimage.paste(image,(w_loc,h_loc))
spriteimage.convert("RGB").save('sprite.jpg', transparency=0)

# %%
im_path = 'sample/images'
im_names = [os.path.join(root, name)
            for root, dirs, files in os.walk(im_path)
            for name in files
            if name.endswith(".jpg")]

# %%
img_list = [os.path.join('sample/images/B09NSZ5QMF', impath) for impath in os.listdir('sample/images/B09NSZ5QMF')]
print(img_list[0])
# Out:
# sample/images/B09NSZ5QMF/B09NSZ5QMF_211_0.jpg

# %%
existing_images_df = pd.DataFrame([re.findall(r"[\w']+", im_name)[2:4] for im_name in img_list],
                                  columns=['pid', 'rid'])

# %%
metadata = existing_images_df[['pid', 'rid']].to_csv('vis/metadata.tsv', sep='\t', index=False)

# %%
from PIL import Image

sprite_image_path = "vis/sprite.jpg"
sprite_image = Image.open(sprite_image_path)
width, height = sprite_image.size

print(f"Sprite image size: {width} x {height}")
# Out:
# Sprite image size: 2700 x 2700

# %% [markdown]
# # metadataframe 만들기

# %%
import json
import pandas as pd
import json
import os
from datetime import datetime

# %%
os.listdir('sample')
# Out:
# ['B07RGM3DYC',
#  'B07BWS4CSM',
#  'B07TVHSDMQ',
#  'B009RTBRVG',
#  'B07HJ84J9M',
#  'B01DDC83C8',
#  'B07V6PKCCG',
#  'B09NSZ5QMF']

# %%
for pid in os.listdir('sample'):

    json_path = f'sample/{pid}/review.json'
    
    with open(json_path, "r") as f:
    data = json.load(f)
    
    # 데이터프레임 생성
    df = pd.DataFrame(data[f'{pid}'])

    # 'rating'와 'save_path' 열을 함께 담은 데이터프레임 생성
    df_ = pd.DataFrame({
        'rating': df['rating'],
        'parent_asin': df['parent_asin'],
        'user_id': df['user_id'],
        'timestamp(unix)': df['timestamp'],
        'timestamp': [datetime.fromtimestamp(ts / 1000) for ts in df['timestamp']],
        'helpful_vote': df['helpful_vote'],
        'save_path': df['images'].apply(lambda x: [item['save_path'] for item in x])
    })
    
    df_ = df_.dropna()
    
    expanded_df = df_('save_path').reset_index(drop=True)
    
    expanded_df['rid'] = expanded_df['save_path'].apply(lambda x: x.split('/')[-1].split('.jpg')[0])
    
    expanded_df = expanded_df[['parent_asin','rid', 'user_id', 'timestamp', 'rating', 'helpful_vote', 'timestamp(unix)', 'save_path']]
    
    
    expanded_df.to_csv(f"sample/{pid}/metadata.tsv", sep='\t', index = False)

# %%
from datasets import load_dataset
from tqdm import tqdm

# meta dataload
meta_dataset = load_dataset("McAuley-Lab/Amazon-Reviews-2023", "raw_meta_Clothing_Shoes_and_Jewelry", split="full", trust_remote_code=True)
print(meta_dataset[0])
print(meta_dataset[1])
# Out:
# Loading dataset shards:   0%|          | 0/31 [00:00<?, ?it/s]
# {'main_category': 'AMAZON FASHION', 'title': "BALEAF Women's Long Sleeve Zip Beach Coverup UPF 50+ Sun Protection Hooded Cover Up Shirt Dress with Pockets", 'average_rating': 4.2, 'rating_number': 422, 'features': ['90% Polyester, 10% Spandex', 'Zipper closure', 'Machine Wash', 'Long sleeve sun protection coverups--UPF 50+ blocks the sun from burning', 'Zipped v-neckline--fashionable V neck and smooth 1/4 zipper allows to staying place as you like', 'Two drop-in side pockets--hold your phone or keys well，no worries of falling out', 'Hoodie with non-slip drawcord--Enhancing hooded design is convenient to wrap your face and enough space to put your head and hair easily', 'A flattering coverups company you spend all day on the beach，traveling with lovers or busying around house. Recommended For everyday leisure or daily exercise'], 'description': [], 'price': '31.99', 'images': {'hi_res': ['https://m.media-amazon.com/images/I/61KIZjb54AL._AC_UL1500_.jpg', 'https://m.media-amazon.com/images/I/61OkTrsW88L._AC_UL1500_.jpg', 'https://m.media-amazon.com/images/I/811lbVuVIAL._AC_UL1500_.jpg', 'https://m.media-amazon.com/images/I/71wa-UQGlYL._AC_UL1500_.jpg', 'https://m.media-amazon.com/images/I/61tspZIpHqL._AC_UL1500_.jpg', 'https://m.media-amazon.com/images/I/71oVECB3VYL._AC_UL1500_.jpg'], 'large': ['https://m.media-amazon.com/images/I/31zPYU+UkVL._AC_.jpg', 'https://m.media-amazon.com/images/I/31LYNX5KQ6L._AC_.jpg', 'https://m.media-amazon.com/images/I/51dD8Ga+wQL._AC_.jpg', 'https://m.media-amazon.com/images/I/41kM3Cn3ERL._AC_.jpg', 'https://m.media-amazon.com/images/I/41ZzITDO+OL._AC_.jpg', 'https://m.media-amazon.com/images/I/51jTzfIP3dL._AC_.jpg'], 'thumb': ['https://m.media-amazon.com/images/I/31zPYU+UkVL._AC_SR38,50_.jpg', 'https://m.media-amazon.com/images/I/31LYNX5KQ6L._AC_SR38,50_.jpg', 'https://m.media-amazon.com/images/I/51dD8Ga+wQL._AC_SR38,50_.jpg', 'https://m.media-amazon.com/images/I/41kM3Cn3ERL._AC_SR38,50_.jpg', 'https://m.media-amazon.com/images/I/41ZzITDO+OL._AC_SR38,50_.jpg', 'https://m.media-amazon.com/images/I/51jTzfIP3dL._AC_SR38,50_.jpg'], 'variant': ['MAIN', 'PT01', 'PT02', 'PT03', 'PT04', 'PT05']}, 'videos': {'title': ["Women's UPF 50+ Front Zip Beach Coverups with Pockets", " Women's Swim Cover Up Dress"], 'url': ['https://www.amazon.com/vdp/0041f3df9f604577bd982078c9f3fec2?ref=dp_vse_rvc_0', 'https://www.amazon.com/vdp/0222bb314b16471a8b43f19080358fdc?ref=dp_vse_rvc_1'], 'user_id': ['', '']}, 'store': 'BALEAF', 'categories': ['Clothing, Shoes & Jewelry', 'Women', 'Clothing', 'Swimsuits & Cover Ups', 'Cover-Ups'], 'details': '{"Department": "womens", "Date First Available": "April 3, 2022"}', 'parent_asin': 'B09X1MRDN6', 'bought_together': None, 'subtitle': None, 'author': None}
# {'main_category': 'AMAZON FASHION', 'title': 'Merrell Work Moab 2 Vent Waterproof SR Boulder', 'average_rating': 2.7, 'rating_number': 4, 'features': ['Rubber sole'], 'description': [], 'price': 'None', 'images': {'hi_res': ['https://m.media-amazon.com/images/I/81oltcdwYSL._AC_UL1500_.jpg'], 'large': ['https://m.media-amazon.com/images/I/41TeICZuYgL._AC_.jpg'], 'thumb': ['https://m.media-amazon.com/images/I/41TeICZuYgL._AC_US40_.jpg'], 'variant': ['MAIN']}, 'videos': {'title': [], 'url': [], 'user_id': []}, 'store': 'Merrell', 'categories': ['Clothing, Shoes & Jewelry', 'Women', 'Shoes', 'Outdoor', 'Hiking & Trekking', 'Hiking Shoes'], 'details': '{"Package Dimensions": "14.02 x 9.29 x 4.8 inches; 1 Pounds", "Item model number": "00-3C4Q7W8I-AX", "Department": "womens", "Date First Available": "November 2, 2017"}', 'parent_asin': 'B073C4Q7W8', 'bought_together': None, 'subtitle': None, 'author': None}

# %%
parent_asin_list = os.listdir('sample')
print(parent_asin_list)
# Out:
# ['B07RGM3DYC', 'B07BWS4CSM', 'B07HJ84J9M', 'B01DDC83C8', 'B07V6PKCCG', 'B09NSZ5QMF']

# %%
from datasets import load_dataset
import os

# Load the dataset
#meta_dataset = load_dataset("McAuley-Lab/Amazon-Reviews-2023", "raw_meta_Clothing_Shoes_and_Jewelry", split="full", trust_remote_code=True)

# Extract parent_asin_list
parent_asin_list = set(os.listdir('sample'))

# Initialize a dictionary to store metadata for parent_asin values in parent_asin_list
selected_metadata = {}

# Iterate through the dataset and find corresponding metadata
for meta in tqdm(meta_dataset):
    if meta['parent_asin'] in parent_asin_list:
        selected_metadata[meta['parent_asin']] = meta

# Print or use selected_metadata as needed
print(selected_metadata)
# Out:
# 100%|███████████████████████████████| 7218481/7218481 [17:31<00:00, 6865.52it/s]
# {'B07RGM3DYC': {'main_category': 'AMAZON FASHION', 'title': 'Columbia womens Newton Ridge Lightweight Waterproof Shoe Hiking Boot, Beach/Marsala Red, 8.5 US', 'average_rating': 4.7, 'rating_number': 199, 'features': ['Imported', 'Rubber sole', 'Shaft measures approximately mid-calf from arch', 'Boot opening measures approximately 1 around', 'ADVANCED TECHNOLOGY: The Newton Ridge Lightweight Waterproof Hiking Boot features a waterproof waxed canvas and suede leather upper construction, combined with our TECHLITE lightweight midsole, for long-lasting comfort with superior cushioning and high energy return', "DURABLE HIKING BOOT: This women's boot is inspired by classic mountaineering style. A durable mid cut waterproof hiker that provides great traction and comfort. This classic Columbia hiking boot, will deliver reliable and comfortable service", 'ALL TERRAIN TRACTION: Our signature Omni-GRIP non-marking traction rubber outsole provides high grip across a wide variety of terrain, and versatile three season use', "HANDY FEATURES: Treacherous days out on the trail are comfortable and worry-free with this hiking boot's waterproof combination of supportive waxed canvas and suede construction", 'REINFORCED TOE AND HEEL CONSTRUCTION: Designed for extended seasons of use, we’ve reinforced the toe and heel barriers, and extended the outsole toe overwrap to guard these key wear points'], 'description': ["Finally, a stylish waterproof hiking boot with the comfort and traction you need for tough trails, easy walks—and every adventure in between. The Newton Ridge Lightweight Waterproof Hiking Boot is made from high quality materials, quality assembly, and durable stitching. It’s a rugged trail-ready boot designed for long-lasting hiking wear. Just lace up and go. These hiking boots feature a waterproof waxed canvas upper with suede leather overlays. Its breathable seam sealed membrane construction offers comfortable dry performance. Along with our Techlite lightweight midsole, you'll find superior cushioning and comfort on any trail. Incorporating mountain oriented outdoor lace hardware, this is a secure and stable boot built for a wide variety of activities. Columbia offers these women's hiking boots with true-to-fit sizing."], 'price': 'None', 'images': {'hi_res': ['https://m.media-amazon.com/images/I/81f6hUSb5tL._AC_UL1500_.jpg', 'https://m.media-amazon.com/images/I/81UGes958XL._AC_UL1500_.jpg', 'https://m.media-amazon.com/images/I/81J0U+1zgKL._AC_UL1500_.jpg', 'https://m.media-amazon.com/images/I/81ZNoagWclL._AC_UL1500_.jpg', 'https://m.media-amazon.com/images/I/81k7OLwn+tL._AC_UL1500_.jpg', 'https://m.media-amazon.com/images/I/814KDzo3BAL._AC_UL1500_.jpg', 'https://m.media-amazon.com/images/I/61L9uhqYtwL._AC_UL1500_.jpg', 'https://m.media-amazon.com/images/I/61tElNphT2L._AC_UL1500_.jpg', 'https://m.media-amazon.com/images/I/61--wq5QGwL._AC_UL1500_.jpg', 'https://m.media-amazon.com/images/I/614sJg4hrBL._AC_UL1500_.jpg', 'https://m.media-amazon.com/images/I/71+Nf-8jWAL._AC_UL1500_.jpg', 'https://m.media-amazon.com/images/I/71oqzeJImWL._AC_UL1500_.jpg', 'https://m.media-amazon.com/images/I/71XDRub7IiL._AC_UL1500_.jpg', 'https://m.media-amazon.com/images/I/711BnFeKeGL._AC_UL1500_.jpg', 'https://m.media-amazon.com/images/I/91suI-ln1uL._AC_UL1500_.jpg', 'https://m.media-amazon.com/images/I/81Kdc4bYVtL._AC_UL1500_.jpg'], 'large': ['https://m.media-amazon.com/images/I/415oTgD3BNL._AC_.jpg', 'https://m.media-amazon.com/images/I/410Ud+iZ4TL._AC_.jpg', 'https://m.media-amazon.com/images/I/41Dc5pgJHNL._AC_.jpg', 'https://m.media-amazon.com/images/I/31pKvi3+M8L._AC_.jpg', 'https://m.media-amazon.com/images/I/41vlaTjwRVL._AC_.jpg', 'https://m.media-amazon.com/images/I/31j954HvwBL._AC_.jpg', 'https://m.media-amazon.com/images/I/31e-YQ+f8+L._AC_.jpg', 'https://m.media-amazon.com/images/I/31-1QkDB5ZL._AC_.jpg', 'https://m.media-amazon.com/images/I/31dKOfU-5JL._AC_.jpg', 'https://m.media-amazon.com/images/I/31WcIyJndzL._AC_.jpg', 'https://m.media-amazo ...

# %%
len(selected_metadata)
# Out:
# 6

# %%
for d in selected_metadata.items():
    save_path = f'sample/{d[0]}/meta.json'
    with open(save_path, "w") as f:
        json.dump(d, f)

# %%
# 이미지 사이즈 확인
file_name = "sample/B01DDC83C8/meta.json"
with open(file_name, "r") as f:
    meta_dict = json.load(f)

# %%
meta_dict[1]['images']['large']
# Out:
# ['https://m.media-amazon.com/images/I/31R3esmCldL._AC_.jpg',
#  'https://m.media-amazon.com/images/I/31SvPAjao3L._AC_.jpg',
#  'https://m.media-amazon.com/images/I/31EspIeodyL._AC_.jpg',
#  'https://m.media-amazon.com/images/I/31aRN-B68jL._AC_.jpg',
#  'https://m.media-amazon.com/images/I/51xu30I14bL._AC_.jpg',
#  'https://m.media-amazon.com/images/I/41EnempJ50L._AC_.jpg',
#  'https://m.media-amazon.com/images/I/51gm4D-F7BL._AC_.jpg']

# %%
from tqdm import tqdm
import os
import json
import requests
# 이미지 다운로드 및 저장 함수 (Download and save image function)
def download_and_save_image(url, img_file_path, retries=3):
    for _ in range(retries):
        try:
            response = requests.get(url, timeout=10)  # Increase timeout to 10 seconds
            if response.status_code == 200:
                with open(img_file_path, 'wb') as f:
                    f.write(response.content)
                return True  # Return True if download is successful
        except Exception as e:
            print(f"Error downloading image: {e}")
    return False  # Return False if download fails after retries

# %%
for url in meta_dict[1]['images']['large']:
    path = f'sample/B01DDC83C8/fgi/{url.split("/")[-1]}'
    download_and_save_image(url, path)
